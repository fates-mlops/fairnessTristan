# %% [markdown]
# <a id="mots-cles"></a>
# # <span style="color:#1E90FF;"> Définitions détaillées des acronymes liés à la transparence en IA </span>

# %% [markdown]
# ### <a id="IRIT"></a><span style="color:#1E90FF;">IRIT</span>
# **Institut de Recherche en Informatique de Toulouse**
#
# Centre de recherche multidisciplinaire rassemblant des experts en IA, systèmes critiques, analyse de données, et interaction homme-machine. L’IRIT joue un rôle clé dans les réflexions sur l’éthique et la régulation de l’intelligence artificielle.
#
#
# ### <a id="FATES"></a><span style="color:#1E90FF;">FATES</span>
# **Fairness, Accountability, Transparency, Ethics, Security**
#
# Cadre structurant les exigences éthiques et sociotechniques en IA :
# - *Fairness* (équité)
# - *Accountability* (responsabilité)
# - *Transparency* (explicabilité)
# - *Ethics* (éthique)
# - *Security* (sécurité)
#
#
# ### <a id="MLOPS"></a><span style="color:#1E90FF;">MLOps</span>
# **Machine Learning Operations**
#
# Pratiques de type DevOps appliquées au déploiement, à la maintenance et à la surveillance des modèles de machine learning en production.
#
#
# ### <a id="HAL"></a><span style="color:#1E90FF;">HAL</span>
# **Hyper Articles en Ligne**
#
# Plateforme française d’archives ouvertes pour publications scientifiques et données de recherche.
# [voir le site HAL](https://hal.archives-ouvertes.fr)
#
#
# ### <a id="ML"></a><span style="color:#1E90FF;">ML</span>
# **Machine Learning (Apprentissage automatique)**
#
# Ensemble de techniques permettant à des algorithmes d’apprendre à partir des données.
#
#
# ### <a id="COMPAS"></a><span style="color:#1E90FF;">COMPAS</span>
# **Correctional Offender Management Profiling for Alternative Sanctions**
#
# Algorithme prédictif dans la justice pénale américaine, critiqué pour son manque de transparence et ses biais.
#
# ### <a id="AI-Driven"></a><span style="color:#1E90FF;">AI-Driven</span>
# Piloté par l’IA
#
# Système ou processus où l’intelligence artificielle joue un rôle central dans la prise de décision.
#
# ### <a id="ASL"></a><span style="color:#1E90FF;">AI Safety Level (ASL)</span>
#
# Le **AI Safety Level** correspond à une classification des systèmes d’IA selon leur niveau de sécurité, basé sur les risques et impacts potentiels qu’ils peuvent engendrer.
#
# - **Niveau 1** : Sécurité faible
#   Systèmes d’IA avec des risques limités, dont les conséquences négatives sont peu probables ou peu graves. Généralement utilisés dans des contextes où une erreur a un faible impact.
#
# - **Niveau 2** : Sécurité modérée
#   Systèmes pouvant présenter des risques plus importants, nécessitant des mécanismes de contrôle et de surveillance pour limiter les effets indésirables potentiels.
#
# - **Niveau 3** : Sécurité élevée
#   Systèmes critiques où les défaillances peuvent entraîner des conséquences graves sur les personnes, les biens ou l’environnement. Une attention forte est portée à la robustesse, la fiabilité et la gestion des risques.
#
# - **Niveau 4** : Sécurité très élevée
#   Systèmes avec un potentiel de risque majeur, qui requièrent des garanties strictes, des audits réguliers, et une supervision humaine constante pour assurer la sécurité.
#
# Cette classification aide à adapter les exigences de sécurité aux différents usages et permet d’orienter le développement et la régulation des IA selon leur criticité.
#
#
# ### <a id="API"></a><span style="color:#1E90FF;">API</span>
# **Application Programming Interface**
#
# Interface permettant la communication entre logiciels ou entre un utilisateur et un système d’IA.
#
#
# ### <a id="GDPR"></a><span style="color:#1E90FF;">GDPR</span>
# **General Data Protection Regulation (RGPD)**
#
# Règlement européen encadrant la protection des données personnelles.
# [Lien vers europa](https://eur-lex.europa.eu/eli/reg/2016/679/oj)
#
#
# ### <a id="AIA"></a><span style="color:#1E90FF;">AIA</span>
# **Artificial Intelligence Agent**
#
# Agent autonome doté de capacités d’apprentissage, de décision et d’action.
#
#
# ### <a id="FERM"></a><span style="color:#1E90FF;">FERM</span>
# **Fair Empirical Risk Minimization**
#
# Méthode visant à équilibrer précision prédictive et équité dans les modèles d’apprentissage.
# [lien d'explication vers IEEE Xplore](https://ieeexplore.ieee.org/abstract/document/9206819)
#
#
# ### <a id="VFAE"></a><span style="color:#1E90FF;">VFAE</span>
# **Variational Fair Autoencoder**
#
# Autoencodeur conçu pour produire des représentations de données neutres vis-à-vis d’attributs sensibles.
#
#
# ### <a id="EIA"></a><span style="color:#1E90FF;">EIA</span>
# **Ethical Impact Assessment**
#
# Évaluation des risques éthiques liés à l’usage d’un système d’IA.
#
#
# ### <a id="SHAP"></a><span style="color:#1E90FF;">SHAP</span>
# **SHapley Additive exPlanations**
#
# Méthode d’explicabilité individuelle inspirée de la théorie des jeux.
#
#
# ### <a id="LIME"></a><span style="color:#1E90FF;">LIME</span>
# **Local Interpretable Model-agnostic Explanations**
#
# Méthode qui explique localement une prédiction par un modèle simplifié.
#
#
# ### <a id="WIT"></a><span style="color:#1E90FF;">WIT</span>
# **What-If Tool**
#
# Outil visuel pour tester et analyser les comportements des modèles de ML.
#
#
# ### <a id="HITL"></a><span style="color:#1E90FF;">HITL</span>
# **Human-In-The-Loop**
#
# Approche dans laquelle l’humain intervient activement dans la boucle de décision de l’IA.
#
#
# ### <a id="HOTL"></a><span style="color:#1E90FF;">HOTL</span>
# **Human-On-The-Loop**
#
# Modèle où l’humain surveille le fonctionnement d’un système automatisé sans intervenir systématiquement.
#
#
# ### <a id="BIAS"></a><span style="color:#1E90FF;">BIAS</span>
# **Business Impact Analysis**
#
# Analyse des effets et risques d’un système IA sur les processus métiers, notamment les biais.

# %% [markdown]
# ## <a id="definitions_generales"></a>Définitions générales  (IA, transparence, responsabilité…)

# %% [markdown]
# - **<a id="ia"></a>Intelligence artificielle (IA)** : Ensemble de techniques permettant à des machines de simuler des fonctions cognitives humaines (raisonnement, apprentissage, perception…).
# - **<a id="transparence"></a>Transparence** : Capacité à rendre compréhensibles, traçables et vérifiables les décisions ou mécanismes d’un système automatisé.
# - **<a id="responsabilite"></a>Responsabilité** : Obligation d’un acteur (humain ou organisation) d’assumer les conséquences de ses décisions ou de celles de l’IA qu’il développe/utilise.
# - **<a id="acceptabilite"></a>Acceptabilité** : Degré d’adhésion ou de tolérance du public envers une technologie, influencé par la confiance, l'éthique et la compréhension.
# - **<a id="fiabilite"></a>Fiabilité** : Capacité d’un système à fonctionner correctement de manière constante, sans erreurs ou comportements imprévus.
# - **<a id="equite"></a>Équité** : Principe d’impartialité dans le traitement des individus, sans discrimination ni biais injustifiés.
# - **<a id="legitimite"></a>Légitimité** : Reconnaissance du caractère justifié ou acceptable d’un système, d’une règle ou d’une décision.
# - **<a id="interoperabilite"></a>Interopérabilité** : Capacité de différents systèmes à fonctionner ensemble, à partager des informations ou des standards.

# %% [markdown]
# ## 🔹 <a id="confiance-explicabilite"></a>Confiance et explicabilité
#
# - **<a id="confiance"></a>Confiance** : Sentiment de sécurité et de fiabilité envers un système, essentiel à son adoption par les utilisateurs.
# - **<a id="explication-intelligible"></a>Explication intelligible** : Explication formulée dans un langage simple, compréhensible par un non-expert.
# - **<a id="explication-locale"></a>Explications locales** : Justifications concernant une décision spécifique prise par un modèle (ex. pourquoi un crédit a été refusé à une personne).
# - **<a id="explication-globale"></a>Explications globales** : Description du fonctionnement général d’un modèle, utile pour comprendre les logiques sous-jacentes ou pour l’évaluer globalement.
#
# ---

# %% [markdown]
# ## 🔹 <a id="techniques"></a>Concepts techniques
#
# - **<a id="logs"></a>Logs (ou historique)** : Enregistrements détaillés des actions ou décisions d’un système, utiles pour les audits ou la traçabilité.
# - **<a id="audits"></a>Audits** : Évaluations indépendantes ou officielles visant à vérifier la conformité, l’éthique ou la performance d’un système.
# - **<a id="suivi-post-deploiement"></a>Suivi post-déploiement** : Surveillance continue d’un système après sa mise en service pour détecter d’éventuels effets indésirables.
# - **<a id="recours"></a>Mécanismes de recours** : Moyens pour un utilisateur de contester ou demander la révision d’une décision automatisée.
# - **<a id="differential-privacy"></a>Differential privacy** : Technique permettant de protéger la confidentialité des données personnelles tout en permettant leur analyse statistique.
# - **<a id="homomorphic-encryption"></a>Homomorphic encryption (chiffrement homomorphe)** : Méthode permettant d’effectuer des calculs sur des données cryptées sans les décrypter.
# - **<a id="watermarking"></a>Watermarking** : Technique consistant à insérer une marque invisible dans les données pour prouver leur origine ou prévenir leur utilisation frauduleuse.
# - **<a id="federation-donnees"></a>Fédération des données** : Méthode permettant d’analyser des données provenant de plusieurs sources sans les centraliser, préservant ainsi la confidentialité.
#
# ---

# %% [markdown]
# ## 🔹 <a id="tensions"></a>Concepts en tension
#
# - **<a id="paradoxe-transparence"></a>Paradoxe de la transparence** : Idée selon laquelle trop de transparence peut nuire à la compréhension, à la sécurité ou à la confiance.
# - **<a id="opacite-algorithmique"></a>Opacité algorithmique** : Situation où les décisions d’un système automatisé ne sont pas compréhensibles, même pour ses concepteurs.
# - **<a id="opacite-cognitive"></a>Opacité cognitive** : Confusion provoquée par un excès de données techniques non vulgarisées.
# - **<a id="contre-productive"></a>Contre-productive** : Qui produit un effet inverse à celui souhaité (ex. perte de légitimité au lieu de confiance).
# - **<a id="tension-transparence-securite"></a>Tension entre transparence et sécurité** : Conflit entre le besoin d’informer et la nécessité de protéger les systèmes contre les attaques.

# %% [markdown]
# ## 🔹 <a id="explicabilite"></a>Technologies d’explicabilité
#
# - **<a id="SHAP"></a>SHAP (Shapley Additive Explanations)** : Méthode d’explicabilité basée sur la théorie des jeux pour attribuer à chaque facteur sa contribution à une décision.
# - **<a id="LIME"></a>LIME (Local Interpretable Model-agnostic Explanations)** : Technique expliquant localement les prédictions d’un modèle en l’approximation par un modèle simple.
# - **<a id="WIT"></a>WIT (What-If Tool)** : Outil visuel permettant de tester l’effet de modifications sur les données d’entrée d’un modèle.

# %% [markdown]
# ## 🔹 <a id="normes"></a>Conformité et normes
#
# - **<a id="AIAct"></a>AI Act** : Règlement européen sur l’intelligence artificielle classant les systèmes selon leur niveau de risque et imposant des exigences spécifiques.
# - **<a id="OCDE"></a>OCDE** : Organisation de coopération et de développement économiques, qui édicte des principes pour une IA responsable.
# - **<a id="UNESCO"></a>UNESCO** : Organisation des Nations unies pour l’éducation, la science et la culture, proposant un cadre éthique pour l’IA.
# - **<a id="ISO"></a>Normes ISO** : Standards techniques internationaux, applicables aussi à la gouvernance et à la sécurité de l’IA.
# - **<a id="GDPR"></a>GDPR (General Data Protection Regulation)** : Règlement européen encadrant la protection des données personnelles.
#   [Lien vers europa](https://eur-lex.europa.eu/eli/reg/2016/679/oj)

# %% [markdown]
# ## 🔹 <a id="pedagogie"></a>Communication et pédagogie
#
# - **<a id="traduction-pedagogique"></a>Traduction pédagogique** : Adaptation du discours technique pour le rendre compréhensible à un public non spécialiste.
# - **<a id="langage-adapte"></a>Langage adapté** : Choix de mots ou d’exemples accessibles selon le niveau du public cible.
# - **<a id="transparence-contextuelle"></a>Transparence contextuelle** : Adaptation du niveau de transparence en fonction du rôle et des besoins du destinataire.
# - **<a id="utilisateurs-finaux"></a>Utilisateurs finaux** : Personnes directement concernées par l’utilisation ou les décisions d’un système IA (ex. citoyens, clients).
# - **<a id="experts-techniques"></a>Experts techniques** : Professionnels ou chercheurs maîtrisant les détails algorithmiques ou informatiques des systèmes IA.

# %% [markdown]
# ## 🔹 <a id="acronymes"></a>Institutions, cadres et acronymes spécialisés
#
# - **<a id="IRIT"></a>IRIT** : Institut de Recherche en Informatique de Toulouse — centre de recherche multidisciplinaire engagé sur l’éthique et la régulation de l’IA.
# - **<a id="FATES"></a>FATES** : *Fairness, Accountability, Transparency, Ethics, Security* – Cadre structurant les exigences éthiques et sociotechniques en IA.
# - **<a id="MLOPS"></a>MLOps** : *Machine Learning Operations* – Pratiques DevOps appliquées au déploiement, à la maintenance et à la surveillance des modèles de ML.
# - **<a id="HAL"></a>HAL** : *Hyper Articles en Ligne* – Plateforme française d’archives ouvertes pour publications scientifiques.
#   [Voir le site HAL](https://hal.archives-ouvertes.fr)
